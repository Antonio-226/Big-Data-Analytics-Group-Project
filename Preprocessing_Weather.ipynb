# %%
import pandas as pd
import os

# %% [markdown]
# Getting the full path to the dataset folder

# %%
dir_path = os.path.dirname(os.path.realpath("__file__"))
path_to_datasets_folder = os.path.join(dir_path, "datasets")
path_to_weather_file = os.path.join(path_to_datasets_folder, "messwerte_mythenquai_2007-2020.csv")

# %%
df_weather = pd.read_csv(path_to_weather_file)
df_weather.head()
# Out:
# C:\tools\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2,8,9,11,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          timestamp_cet  air_temperature water_temperature  \
# 0  2007-04-22T21:20:00             18.9              15.2
# 1  2007-04-22T21:30:00             18.1              15.2
# 2  2007-04-22T21:40:00             17.7              15.1
# 3  2007-04-22T21:50:00             17.6              15.3
# 4  2007-04-22T22:00:00             17.4              15.4
#
#    wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                  1.6                   0.7                   0.7
# 1                  1.3                   0.8                   0.8
# 2                  0.9                   0.2                   0.2
# 3                  0.6                   0.1                   0.1
# 4                  0.7                   0.3                   0.3
#
#    wind_direction  windchill barometric_pressure_qfe precipitation  dew_point  \
# 0             321       18.9                   973.5             0        4.4
# 1             346       18.1                   973.7             0        4.8
# 2               4       17.7                   973.7             0        5.1
# 3             235       17.6                   973.8             0        5.7
# 4             178       17.4                   973.9             0        6.3
#
#   global_radiation  humidity water_level
# 0                3        38      405.94
# 1                3        41      405.94
# 2                3        43      405.94
# 3                3        45      405.94
# 4                3        48      405.94

# %% [markdown]
# Drop all rows before 2011

# %%
#df_weather = df_weather[df_weather.timestamp_cet != '2007']
df_weather[~df_weather.timestamp_cet.str.get(0).isin(['2007', '2008'])]
# Out:
#               timestamp_cet  air_temperature water_temperature  \
# 0       2007-04-22T21:20:00             18.9              15.2
# 1       2007-04-22T21:30:00             18.1              15.2
# 2       2007-04-22T21:40:00             17.7              15.1
# 3       2007-04-22T21:50:00             17.6              15.3
# 4       2007-04-22T22:00:00             17.4              15.4
# ...                     ...              ...               ...
# 708359  2020-12-31T23:20:00              2.1                 .
# 708360  2020-12-31T23:30:00              2.1                 .
# 708361  2020-12-31T23:40:00              2.1                 .
# 708362  2020-12-31T23:50:00              2.2                 .
# 708363  2021-01-01T00:00:00              2.5                 .
#
#         wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                       1.6                   0.7                   0.7
# 1                       1.3                   0.8                   0.8
# 2                       0.9                   0.2                   0.2
# 3                       0.6                   0.1                   0.1
# 4                       0.7                   0.3                   0.3
# ...                     ...                   ...                   ...
# 708359                  2.5                   1.8                   2.0
# 708360                  2.6                   1.8                   2.0
# 708361                  2.5                   1.7                   2.0
# 708362                  1.8                   1.0                   1.0
# 708363                  1.6                   0.9                   1.0
#
#         wind_direction  windchill barometric_pressure_qfe precipitation  \
# 0                  321       18.9                   973.5             0
# 1                  346       18.1                   973.7             0
# 2                    4       17.7                   973.7             0
# 3                  235       17.6                   973.8             0
# 4                  178       17.4                   973.9             0
# ...                ...        ...                     ...           ...
# 708359             293        1.8                    1005             .
# 708360             303        1.7                    1005             .
# 708361             305        2.0                    1005             .
# 708362             318        2.2                    1005             .
# 708363              16        2.5                    1005             .
#
#         dew_point global_radiation  humidity water_level
# 0             4.4                3        38      405.94
# 1             4.8                3        41      405.94
# 2             5.1                3        43      405.94
# 3             5.7                3        45      405.94
# 4             6.3                3        48      405.94
# ...           ...              ...       ...         ...
# 708359        0.4                .        89           .
# 708360        0.6                .        89           .
# 708361        0.7                .        90           .
# 708362        0.8                .        91           .
# 708363        1.4                .        92           .
#
# [708364 rows x 14 columns]

# %%
df_weather = df_weather[~df_weather['timestamp_cet'].astype(str).str.startswith(['2007', '2008'])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-043a42e0610f> in <module>
# ----> 1 df_weather = df_weather[~df_weather['timestamp_cet'].astype(str).str.startswith(['2007', '2008'])]
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1322             return self
#    1323
# -> 1324         new_data = self._mgr.apply(operator.invert)
#    1325         result = self._constructor(new_data).__finalize__(self, method="__invert__")
#    1326         return result
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     402
#     403             if callable(f):
# --> 404                 applied = b.apply(f, **kwargs)
#     405             else:
#     406                 applied = getattr(b, f)(**kwargs)
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     344         """
#     345         with np.errstate(all="ignore"):
# --> 346             result = func(self.values, **kwargs)
#     347
#     348         return self._split_op_result(result)
#
# TypeError: ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df_weather.head()
# Out:
#              timestamp_cet  air_temperature water_temperature  \
# 36448  2008-01-01T00:00:00             -1.0               5.5
# 36449  2008-01-01T00:10:00             -0.9               5.5
# 36450  2008-01-01T00:20:00             -0.9               5.4
# 36451  2008-01-01T00:30:00             -1.2               5.4
# 36452  2008-01-01T00:40:00             -1.0               5.4
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 36448                  0.0                   0.0                   0.0
# 36449                  1.2                   0.8                   0.8
# 36450                  1.9                   1.2                   1.2
# 36451                  1.9                   1.3                   1.3
# 36452                  2.1                   1.5                   1.5
#
#        wind_direction  windchill barometric_pressure_qfe precipitation  \
# 36448             190       -1.0                     979             0
# 36449             183       -0.9                   978.9             0
# 36450             193       -0.9                   978.8             0
# 36451             203       -1.2                   978.7             0
# 36452             196       -1.0                   978.8             0
#
#        dew_point global_radiation  humidity water_level
# 36448       -2.8                2        87      405.83
# 36449       -2.8                2        87      405.83
# 36450       -2.7                3        87      405.82
# 36451       -3.0                2        87      405.83
# 36452       -2.9                3        87      405.83
